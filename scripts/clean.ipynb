# %% [markdown]
# Historical Data Cleaning
# 11/13/25

# %%
import time
start = time.time()
import pandas as pd
print("pandas import time:", time.time() - start)
# Out:
# Exception ignored in PyObject_HasAttr(); consider using PyObject_HasAttrWithError(), PyObject_GetOptionalAttr() or PyObject_GetAttr():
# Traceback (most recent call last):
#   File "<frozen importlib._bootstrap>", line 488, in _call_with_frames_removed
# AttributeError: partially initialized module 'pandas' from '/Users/areuschel/Desktop/Dsci/Github Repos/Smart-Closet/smartcloset_env/lib/python3.13/site-packages/pandas/__init__.py' has no attribute '_pandas_parser_CAPI' (most likely due to a circular import)
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[2], line 3
#       1 import time
#       2 start = time.time()
# ----> 3 import pandas as pd
#       4 print("pandas import time:", time.time() - start)
#
# File ~/Desktop/Dsci/Github Repos/Smart-Closet/smartcloset_env/lib/python3.13/site-packages/pandas/__init__.py:139
# ...

# %%
import sys
print(sys.path)
# Out:
# ['/opt/anaconda3/lib/python313.zip', '/opt/anaconda3/lib/python3.13', '/opt/anaconda3/lib/python3.13/lib-dynload', '', '/Users/areuschel/Desktop/Dsci/Github Repos/Smart-Closet/smartcloset_env/lib/python3.13/site-packages']
